# %%
import os
import re
from datetime import datetime, timedelta
import pandas as pd
import numpy as np

# %%
links= {'100':['ap-am', 'am-ap', 'ap-pa', 'pa-ap', 'pa-to', 'to-pa', 'to-df', 'df-to', 'df-mt', 'mt-df', 'mt-ro', 'ro-mt', 'mt-ms', 'ms-mt', 'df-ma', 'ma-df', 'ma-pi', 'pi-ma', 'pi-ba', 'ba-pi', 'df-rj', 'rj-df', 'rj-es', 'es-rj', 'ba-df', 'df-ba', 'pi-ce', 'ce-pi', 'ce-rn', 'rn-ce', 'rn-pb', 'pb-rn', 'pb-pe', 'pe-pb', 'pe-al', 'al-pe', 'al-se', 'se-al', 'se-ba', 'ba-se', 'ce-ba', 'ba-ce', 'ba-mg', 'mg-ba', 'ba-es', 'es-ba', 'mg-sp', 'sp-mg', 'sp-rs', 'rs-sp', 'pr-sc', 'sc-pr', 'rs-sc', 'sc-rs'], '200':['ce-sp', 'sp-ce', 'rj-sp', 'sp-rj', 'pr-rs', 'rs-pr'], '300':['pr-sp', 'sp-pr'], '40':['pb-ba', 'ba-pb'], '20':['go-df', 'df-go', 'df-sp', 'sp-df', 'mg-rj', 'rj-mg'], '6':['ac-ro', 'ro-ac'], '3':['am-df', 'df-am'], '1':['am-rr', 'rr-am', 'rr-ce', 'ce-rr'], '10':['mt-go', 'go-mt', 'ms-go', 'go-ms', 'ms-pr', 'pr-ms', 'df-mg', 'mg-df', 'mg-es', 'es-mg', 'pa-ma', 'ma-pa', 'df-ce', 'ce-df']}

# %%
def contar_ocorrencias(row): #aqui eu conto o numero de saltos 
        ocorrencias = row.astype(str).str.contains('bkb.rnp.br|No Hostname|pop').sum() #bkb.rnp.br
        return ocorrencias

def substituir_prefixo(df):
    def processar_celula(valor):
        if isinstance(valor, str):
            if '.bkb.rnp.br' in valor:
                prefixo = valor.split('.')[0].split('-')
                prefixo = prefixo[0] + '-' + prefixo[1]
                prefixo = re.sub(r'\d+|lan|mx', '', prefixo)
                partes = prefixo.split('-')
                if len(partes) > 0 and len(partes[0]) == 3:
                    partes[0] = partes[0][1:] 
                if len(partes) > 1 and len(partes[1]) == 3:
                    partes[1] = partes[1][1:] 
                return '-'.join(partes)
            else:
                return np.nan
        else:
            return np.nan

    colunas_para_processar = df.columns[~df.columns.isin(['Vazao','Vazao_bbr', 'Atraso(ms)', 'Timestamp_cubic', 'Hop_count'])]

    df[colunas_para_processar] = df[colunas_para_processar].map(processar_celula)
    
    return df


def obter_menor_chave(linha, links):
    chaves_encontradas = []
    links_gargalo = []
    
    for link in linha:
        for chave, valores in links.items():
            if link in valores:
                chaves_encontradas.append(int(chave))
                links_gargalo.append(link)

    if chaves_encontradas:
        menor_chave = min(chaves_encontradas)
        indice_menor = chaves_encontradas.index(menor_chave)
        link_gargalo = links_gargalo[indice_menor]
        return menor_chave, link_gargalo
    else:
        return np.nan, np.nan 

def aplicar_bottleneck(df, links):
    retorno = df.apply(lambda linha: obter_menor_chave(linha, links), axis=1, result_type='expand')
    
    if retorno.shape[1] != 2:
        print("Erro: Função obter_menor_chave não está retornando duas colunas para algumas linhas.")
        print("Cabeçalho de retorno para depuração:\n", retorno.head())
        print("Dimensões esperadas: 2 colunas. Dimensões atuais:", retorno.shape[1])
        
        retorno = retorno.reindex(columns=[0, 1]).fillna(np.nan)

    df[['Bottleneck', 'Link_bottleneck']] = retorno
    return df


def selecionar_colunas(df):
    colunas_desejadas = ['Timestamp_cubic', 'Vazao', 'Vazao_bbr', 'Atraso(ms)','Hop_count', 'Bottleneck', 'Link_bottleneck']
    return df[colunas_desejadas]

# %%
local_vazaocubic = '../datasets/originals/datasets vazao/cubic/'
local_vazaobbr = '../datasets/originals/datasets vazao/bbr/'
local_traceroute = '../datasets/originals/datasets traceroute/'
local_atraso = '../datasets/originals/datasets atraso/'
local_destino = '../datasets/pos-process/'

if not os.path.exists(local_destino):
    os.makedirs(local_destino)

tolerance_seconds = 6*3600

def merge_with_tolerance(df1, df2, left_on, right_on, tolerance, suffixes=('_x', '_y')):
    return pd.merge_asof(df1, df2, left_on=left_on, right_on=right_on, direction='nearest', tolerance=tolerance, suffixes=suffixes)

for arquivo1 in sorted(os.listdir(local_vazaocubic)):
    
    with open(local_vazaocubic + arquivo1, 'r') as f:
        line_count = sum(1 for line in f) - 1  # Subtrai 1 para ignorar o cabeçalho

    if line_count < 10:
        print(f"O arquivo {arquivo1} é muito pequeno.")
        continue
        

    nome_links1 = re.findall(r"\b\w{2}-\w{2}\b", arquivo1[:50])
    
    df_vazao_cubic = pd.read_csv(local_vazaocubic + arquivo1)
    
    df_vazao_cubic = df_vazao_cubic.rename(columns={'Timestamp': 'Timestamp_cubic'})
    

    merged = df_vazao_cubic.sort_values('Timestamp_cubic')


    bbr_file = next((f for f in os.listdir(local_vazaobbr) if re.findall(r"\b\w{2}-\w{2}\b", f[:50])[0] == nome_links1[0]), None)
    if bbr_file:
        df_vazao_bbr = pd.read_csv(local_vazaobbr + bbr_file)
        df_vazao_bbr = df_vazao_bbr.rename(columns={'Timestamp': 'Timestamp_bbr'})
        df_vazao_bbr = df_vazao_bbr.sort_values('Timestamp_bbr')
        
        merged = merge_with_tolerance(merged, df_vazao_bbr, left_on='Timestamp_cubic', right_on='Timestamp_bbr', tolerance=tolerance_seconds, suffixes=('', '_bbr'))

    traceroute_file = next((f for f in os.listdir(local_traceroute) if re.findall(r"\b\w{2}-\w{2}\b", f[:40])[0] == nome_links1[0]), None)
    if traceroute_file:
        try:
            df_traceroute = pd.read_csv(local_traceroute + traceroute_file, header=None, engine='python', on_bad_lines='skip')
            df_traceroute.columns = ['Timestamp_traceroute'] + list(df_traceroute.columns[1:])
            df_traceroute = df_traceroute.sort_values('Timestamp_traceroute')
            merged = merge_with_tolerance(merged, df_traceroute, left_on='Timestamp_cubic', right_on='Timestamp_traceroute', tolerance=tolerance_seconds)

        except pd.errors.ParserError as e:
            print(f"Erro ao ler o arquivo {traceroute_file}: {e}")
            continue

    atraso_file = next((f for f in os.listdir(local_atraso) if re.findall(r"\b\w{2}-\w{2}\b", f[:50])[0] == nome_links1[0]), None)
    if atraso_file:
        df_atraso = pd.read_csv(local_atraso + atraso_file)
        df_atraso = df_atraso.rename(columns={'Timestamp': 'Timestamp_atraso'})
        df_atraso = df_atraso.sort_values('Timestamp_atraso')
        
        merged = merge_with_tolerance(merged, df_atraso, left_on='Timestamp_cubic', right_on='Timestamp_atraso', tolerance=tolerance_seconds)

    columns_to_check = ['Vazao', 'Vazao_bbr', 'Atraso(ms)', 'Timestamp_cubic']
    merged = merged.dropna(subset=columns_to_check)

    
    merged = merged.drop(columns=['Data_x','Data_y','Timestamp_traceroute','Timestamp_atraso']) #'Timestamp_bbr'
    
    #aqui vou chamar as funcoes de numero de saltos e gargalo do traceroute 
    merged['Hop_count'] = merged.apply(contar_ocorrencias, axis=1)
    # aqui a gente perde os valores das outras colunas -  se quiser o timestamp bbr vamos precisar ajustar isso
    merged = substituir_prefixo(merged)
    merged = aplicar_bottleneck(merged, links)
    merged = selecionar_colunas(merged)
    
    

    columns_to_check = ['Vazao', 'Vazao_bbr', 'Atraso(ms)', 'Timestamp_cubic', 'Hop_count', 'Bottleneck', 'Link_bottleneck']
    merged = merged.dropna(subset=columns_to_check)
    
    
    merged.rename(columns={'Vazao': 'Vazao_cubic'}, inplace=True)
    if not merged.empty:
        output_file = os.path.join(local_destino, f"dataset-completo-{nome_links1[0]}.csv")
        output_file_full_path = os.path.abspath(output_file)
        print(f"Caminho completo do arquivo de saída: {output_file_full_path}")

        try:
            merged.to_csv(output_file, index=False)
            print(f"Arquivo gerado: {output_file}")
        except Exception as e:
            print(f"Erro ao salvar o arquivo {output_file}: {e}")
    else:
        print(f"Nenhum dado correspondente encontrado para: {arquivo1}")

print("Processamento concluído!")
# Out:
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-am.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-am.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-ap.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-ap.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-ba.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-ba.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-ce.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-ce.csv
# O arquivo cubic esmond data ac-df 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-es.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-es.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-go.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-go.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-ma.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-ma.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-mg.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-mg.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-ms.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-ms.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-mt.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-mt.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-pa.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-pa.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-pb.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-pb.csv
# O arquivo cubic esmond data ac-pe 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-pi.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-pi.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-pr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-pr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-rj.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-rj.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-rn.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-rn.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-ro.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-ro.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-rr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-rr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-rs.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-rs.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-sc.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-sc.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-se.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-se.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-sp.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-sp.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ac-to.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ac-to.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-ac.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-ac.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-ap.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-ap.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-ba.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-ba.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-ce.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-ce.csv
# O arquivo cubic esmond data am-df 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-es.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-es.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-go.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-go.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-ma.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-ma.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-mg.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-mg.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-ms.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-ms.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-mt.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-mt.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-pa.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-pa.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-pb.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-pb.csv
# O arquivo cubic esmond data am-pe 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-pi.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-pi.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-pr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-pr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-rj.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-rj.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-rn.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-rn.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-ro.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-ro.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-rr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-rr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-rs.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-rs.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-sc.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-sc.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-se.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-se.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-sp.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-sp.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-am-to.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-am-to.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-ac.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-ac.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-am.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-am.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-ba.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-ba.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-ce.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-ce.csv
# O arquivo cubic esmond data ap-df 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-es.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-es.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-go.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-go.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-ma.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-ma.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-mg.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-mg.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-ms.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-ms.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-mt.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-mt.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-pa.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-pa.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-pb.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-pb.csv
# O arquivo cubic esmond data ap-pe 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-pi.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-pi.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-pr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-pr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-rj.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-rj.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-rn.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-rn.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-ro.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-ro.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-rr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-rr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-rs.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-rs.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-sc.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-sc.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-se.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-se.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-sp.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-sp.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ap-to.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ap-to.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-ac.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-ac.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-am.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-am.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-ap.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-ap.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-ce.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-ce.csv
# O arquivo cubic esmond data ba-df 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-es.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-es.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-go.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-go.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-ma.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-ma.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-mg.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-mg.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-ms.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-ms.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-mt.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-mt.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-pa.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-pa.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-pb.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-pb.csv
# O arquivo cubic esmond data ba-pe 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-pi.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-pi.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-pr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-pr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-rj.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-rj.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-rn.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-rn.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-ro.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-ro.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-rr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-rr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-rs.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-rs.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-sc.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-sc.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-se.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-se.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-sp.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-sp.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ba-to.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ba-to.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-ac.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-ac.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-am.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-am.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-ap.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-ap.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-ba.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-ba.csv
# O arquivo cubic esmond data ce-df 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-es.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-es.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-go.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-go.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-ma.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-ma.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-mg.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-mg.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-ms.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-ms.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-mt.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-mt.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-pa.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-pa.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-pb.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-pb.csv
# O arquivo cubic esmond data ce-pe 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-pi.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-pi.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-pr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-pr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-rj.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-rj.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-rn.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-rn.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-ro.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-ro.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-rr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-rr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-rs.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-rs.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-sc.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-sc.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-se.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-se.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-sp.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-sp.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ce-to.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ce-to.csv
# O arquivo cubic esmond data df-ac 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-am 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-ap 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-ba 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-ce 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-es 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-go 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-ma 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-mg 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-ms 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-mt 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-pa 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-pb 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-pe 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-pi 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-pr 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-rj 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-rn 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-ro 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-rr 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-df-rs.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-df-rs.csv
# O arquivo cubic esmond data df-sc 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-se 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data df-sp 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-df-to.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-df-to.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-ac.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-ac.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-am.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-am.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-ap.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-ap.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-ba.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-ba.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-ce.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-ce.csv
# O arquivo cubic esmond data es-df 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-go.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-go.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-ma.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-ma.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-mg.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-mg.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-ms.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-ms.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-mt.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-mt.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-pa.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-pa.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-pb.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-pb.csv
# O arquivo cubic esmond data es-pe 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-pi.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-pi.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-pr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-pr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-rj.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-rj.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-rn.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-rn.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-ro.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-ro.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-rr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-rr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-rs.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-rs.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-sc.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-sc.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-se.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-se.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-sp.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-sp.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-es-to.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-es-to.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-ac.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-ac.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-am.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-am.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-ap.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-ap.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-ba.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-ba.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-ce.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-ce.csv
# O arquivo cubic esmond data go-df 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-es.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-es.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-ma.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-ma.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-mg.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-mg.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-ms.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-ms.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-mt.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-mt.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-pa.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-pa.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-pb.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-pb.csv
# O arquivo cubic esmond data go-pe 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-pi.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-pi.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-pr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-pr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-rj.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-rj.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-rn.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-rn.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-ro.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-ro.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-rr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-rr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-rs.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-rs.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-sc.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-sc.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-se.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-se.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-sp.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-sp.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-go-to.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-go-to.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-ac.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-ac.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-am.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-am.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-ap.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-ap.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-ba.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-ba.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-ce.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-ce.csv
# O arquivo cubic esmond data ma-df 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-es.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-es.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-go.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-go.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-mg.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-mg.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-ms.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-ms.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-mt.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-mt.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-pa.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-pa.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-pb.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-pb.csv
# O arquivo cubic esmond data ma-pe 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-pi.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-pi.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-pr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-pr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-rj.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-rj.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-rn.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-rn.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-ro.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-ro.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-rr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-rr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-rs.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-rs.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-sc.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-sc.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-se.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-se.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-sp.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-sp.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-ma-to.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-ma-to.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-mg-ac.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-mg-ac.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-mg-am.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-mg-am.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-mg-ap.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-mg-ap.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-mg-ba.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-mg-ba.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-mg-ce.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-mg-ce.csv
# O arquivo cubic esmond data mg-df 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-mg-es.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-mg-es.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-mg-go.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-mg-go.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-mg-ma.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-mg-ma.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-mg-ms.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-mg-ms.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-mg-mt.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-mg-mt.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-mg-pa.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-mg-pa.csv
# O arquivo cubic esmond data mg-pb 07-13-2024.csv é muito pequeno.
# O arquivo cubic esmond data mg-pe 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-mg-pi.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-mg-pi.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-mg-pr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-mg-pr.csv
# ...
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-ac.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-am.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-am.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-ap.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-ap.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-ba.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-ba.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-ce.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-ce.csv
# O arquivo cubic esmond data se-df 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-es.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-es.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-go.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-go.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-ma.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-ma.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-mg.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-mg.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-ms.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-ms.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-mt.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-mt.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-pa.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-pa.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-pb.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-pb.csv
# O arquivo cubic esmond data se-pe 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-pi.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-pi.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-pr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-pr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-rj.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-rj.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-rn.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-rn.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-ro.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-ro.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-rr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-rr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-rs.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-rs.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-sc.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-sc.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-sp.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-sp.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-se-to.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-se-to.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-ac.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-ac.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-am.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-am.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-ap.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-ap.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-ba.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-ba.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-ce.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-ce.csv
# O arquivo cubic esmond data sp-df 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-es.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-es.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-go.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-go.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-ma.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-ma.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-mg.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-mg.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-ms.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-ms.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-mt.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-mt.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-pa.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-pa.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-pb.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-pb.csv
# O arquivo cubic esmond data sp-pe 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-pi.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-pi.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-pr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-pr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-rj.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-rj.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-rn.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-rn.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-ro.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-ro.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-rr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-rr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-rs.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-rs.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-sc.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-sc.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-se.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-se.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-sp-to.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-sp-to.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-ac.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-ac.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-am.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-am.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-ap.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-ap.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-ba.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-ba.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-ce.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-ce.csv
# O arquivo cubic esmond data to-df 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-es.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-es.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-go.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-go.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-ma.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-ma.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-mg.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-mg.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-ms.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-ms.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-mt.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-mt.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-pa.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-pa.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-pb.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-pb.csv
# O arquivo cubic esmond data to-pe 07-13-2024.csv é muito pequeno.
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-pi.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-pi.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-pr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-pr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-rj.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-rj.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-rn.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-rn.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-ro.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-ro.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-rr.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-rr.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-rs.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-rs.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-sc.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-sc.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-se.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-se.csv
# Caminho completo do arquivo de saída: /home/malu/Área de Trabalho/SBRC-REGRESSAO/ESTIMATIVA-REGRESSAO-SBRC-2025/datasets/pos-process/dataset-completo-to-sp.csv
# Arquivo gerado: ../datasets/pos-process/dataset-completo-to-sp.csv
# Processamento concluído!
